# %%
import torch
import torch.nn.functional as F
import sympy as sp
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
device = torch.device("cuda:4" if torch.cuda.is_available() else "cpu")

# %%
df = pd.read_csv('physics_equations.csv')

functions = []
num_vars_per_func = []

for _, row in df.iterrows():
    formula = row['Formula']
    num_vars = row['# variables']
    function_details = {
        'formula': formula,
        'variables': []
    }
    
    for i in range(1, 11):  
        v_name = row.get(f'v{i}_name', None)
        v_low = row.get(f'v{i}_low', None)
        v_high = row.get(f'v{i}_high', None)
        
        if pd.notna(v_name):
            function_details['variables'].append({
                'name': v_name,
                'low': v_low,
                'high': v_high
            })
    
    functions.append(function_details)
    num_vars_per_func.append(num_vars)

# %%
for i, func in enumerate(functions):
    print(f"Function {i+1}:")
    print(f"  Formula: {func['formula']}")
    print(f"  Number of Variables: {num_vars_per_func[i]}")
    print("  Variables:")
    for var in func['variables']:
        print(f"    - Name: {var['name']}, Range: ({var['low']}, {var['high']})")
    print()
# Out:
# Function 1:
#   Formula: a*x**2 + b*x + c
#   Number of Variables: 3
#   Variables:
#     - Name: a, Range: (0.1, 1)
#     - Name: b, Range: (-1.0, 1.0)
#     - Name: c, Range: (-1.0, 1.0)
#
# Function 2:
#   Formula: k*x
#   Number of Variables: 1
#   Variables:
#     - Name: k, Range: (-1.0, 1)
#
# Function 3:
#   Formula: a*x**2/2
#   Number of Variables: 1
#   Variables:
#     - Name: a, Range: (0.1, 1)
#
# Function 4:
#   Formula: G*m1*m2/x**2
#   Number of Variables: 3
#   Variables:
#     - Name: G, Range: (0.1, 1)
#     - Name: m1, Range: (0.1, 1.0)
#     - Name: m2, Range: (0.1, 1.0)
#
# Function 5:
#   Formula: p*g*x
#   Number of Variables: 2
#   Variables:
#     - Name: p, Range: (0.1, 1)
#     - Name: g, Range: (0.1, 1.0)
#
# Function 6:
#   Formula: (a*x**2 + b*x)/(c*x**2 + d*x + e)
#   Number of Variables: 5
#   Variables:
#     - Name: a, Range: (-1.0, 1)
#     - Name: b, Range: (-1.0, 1.0)
#     - Name: c, Range: (-1.0, 1.0)
#     - Name: d, Range: (-1.0, 1.0)
#     - Name: e, Range: (-1.0, 1.0)
#
# Function 7:
#   Formula: k*x**3
#   Number of Variables: 1
#   Variables:
#     - Name: k, Range: (-1.0, 1)
#
# Function 8:
#   Formula: a*x**3/(b + c*x + d*x**2)
#   Number of Variables: 4
#   Variables:
#     - Name: a, Range: (-1.0, 1)
#     - Name: b, Range: (0.1, 1.0)
#     - Name: c, Range: (-1.0, 1.0)
#     - Name: d, Range: (0.0, 1.0)
#
# Function 9:
#   Formula: s*A*x**4
#   Number of Variables: 2
#   Variables:
#     - Name: s, Range: (0.0, 1)
#     - Name: A, Range: (0.0, 1.0)
#
# Function 10:
#   Formula: t/x
#   Number of Variables: 1
#   Variables:
#     - Name: t, Range: (-1.0, 1)
#
# Function 11:
#   Formula: m*x**2*w
#   Number of Variables: 2
#   Variables:
#     - Name: m, Range: (0.1, 1)
#     - Name: w, Range: (-1.0, 1.0)
#
# Function 12:
#   Formula: P*x
#   Number of Variables: 1
#   Variables:
#     - Name: P, Range: (0.0, 1)
#
# Function 13:
#   Formula: a*x**4 + b*x**2
#   Number of Variables: 2
#   Variables:
#     - Name: a, Range: (0.1, 1)
#     - Name: b, Range: (-1.0, 1.0)
#
# Function 14:
#   Formula: exp(k*x)
#   Number of Variables: 1
#   Variables:
#     - Name: k, Range: (-1.0, 1)
#
# Function 15:
#   Formula: G*M/(x**2)*(1 - 2*G*M/(x*c**2))
#   Number of Variables: 3
#   Variables:
#     - Name: G, Range: (0.1, 1)
#     - Name: M, Range: (0.1, 1.0)
#     - Name: c, Range: (0.1, 1.0)
#
# Function 16:
#   Formula: x**(1/n)
#   Number of Variables: 1
#   Variables:
#     - Name: n, Range: (0.1, 1)
#
# Function 17:
#   Formula: a/(x + b)
#   Number of Variables: 2
#   Variables:
#     - Name: a, Range: (0.1, 1)
#     - Name: b, Range: (0.1, 1.0)
#
# Function 18:
#   Formula: 1/(a*x**2 + b*x + c)
#   Number of Variables: 3
#   Variables:
#     - Name: a, Range: (0.1, 1)
#     - Name: b, Range: (-1.0, 1.0)
#     - Name: c, Range: (0.1, 1.0)
#
# Function 19:
#   Formula: x/(a + b*x)
#   Number of Variables: 2
#   Variables:
#     - Name: a, Range: (0.1, 1)
#     - Name: b, Range: (-1.0, 1.0)
#
# Function 20:
#   Formula: a*x**(3/2) + b*sqrt(x)
#   Number of Variables: 2
#   Variables:
#     - Name: a, Range: (-1.0, 1)
#     - Name: b, Range: (-1.0, 1.0)
#
# Function 21:
#   Formula: c*(x**2 + d)/(x + e)
#   Number of Variables: 3
#   Variables:
#     - Name: c, Range: (-1.0, 1)
#     - Name: d, Range: (0.0, 1.0)
#     - Name: e, Range: (0.0, 1.0)
#
# Function 22:
#   Formula: a*x*log(b*x)
#   Number of Variables: 2
#   Variables:
#     - Name: a, Range: (-1.0, 1)
#     - Name: b, Range: (0.1, 1.0)
#
# Function 23:
#   Formula: c*(exp(d*x) - 1)/x
#   Number of Variables: 2
#   Variables:
#     - Name: c, Range: (-1.0, 1)
#     - Name: d, Range: (-1.0, 1.0)
#
# Function 24:
#   Formula: a*x**b*exp(-c*x)
#   Number of Variables: 3
#   Variables:
#     - Name: a, Range: (0.1, 1)
#     - Name: b, Range: (0.1, 1.0)
#     - Name: c, Range: (0.0, 1.0)
#
# Function 25:
#   Formula: d*(1 - exp(-e*x))
#   Number of Variables: 2
#   Variables:
#     - Name: d, Range: (-1.0, 1)
#     - Name: e, Range: (0.0, 1.0)
#
# Function 26:
#   Formula: c/(1 + exp(-d*(x-e)))
#   Number of Variables: 3
#   Variables:
#     - Name: c, Range: (-1.0, 1)
#     - Name: d, Range: (0.1, 1.0)
#     - Name: e, Range: (-1.0, 1.0)
#
# Function 27:
#   Formula: d*Abs(x - e)
#   Number of Variables: 2
#   Variables:
#     - Name: d, Range: (-1.0, 1)
#     - Name: e, Range: (-1.0, 1.0)
#
# Function 28:
#   Formula: a*sqrt(x**2 + b**2)
#   Number of Variables: 2
#   Variables:
#     - Name: a, Range: (0.0, 1)
#     - Name: b, Range: (0.0, 1.0)
#
# Function 29:
#   Formula: c*(x**2 - d**2)**2
#   Number of Variables: 2
#   Variables:
#     - Name: c, Range: (0.0, 1)
#     - Name: d, Range: (0.0, 1.0)
#
# Function 30:
#   Formula: e*(x**3 - 3*a*x)
#   Number of Variables: 2
#   Variables:
#     - Name: e, Range: (-1.0, 1)
#     - Name: a, Range: (0.0, 1.0)
#
# Function 31:
#   Formula: b*(x**4 - 6*c*x**2 + d)
#   Number of Variables: 3
#   Variables:
#     - Name: b, Range: (-1.0, 1)
#     - Name: c, Range: (0.0, 1.0)
#     - Name: d, Range: (-1.0, 1.0)
#
# Function 32:
#   Formula: a*x**(2/3) + e*x**(1/3)
#   Number of Variables: 2
#   Variables:
#     - Name: a, Range: (-1.0, 1)
#     - Name: e, Range: (-1.0, 1.0)
#
# Function 33:
#   Formula: b*(x + c)*log(x + d)
#   Number of Variables: 3
#   Variables:
#     - Name: b, Range: (-1.0, 1)
#     - Name: c, Range: (0.0, 1.0)
#     - Name: d, Range: (0.1, 1.0)
#
# Function 34:
#   Formula: e*x*(1 - x/a)
#   Number of Variables: 2
#   Variables:
#     - Name: e, Range: (-1.0, 1)
#     - Name: a, Range: (0.1, 1.0)
#
# Function 35:
#   Formula: b*x/(c + x**2)
#   Number of Variables: 2
#   Variables:
#     - Name: b, Range: (-1.0, 1)
#     - Name: c, Range: (0.0, 1.0)
#
# Function 36:
#   Formula: e*x/(1 + b*x**2)
#   Number of Variables: 2
#   Variables:
#     - Name: e, Range: (-1.0, 1)
#     - Name: b, Range: (0.0, 1.0)
#
# Function 37:
#   Formula: a*(x**2 - c**2)/(x**2 + d**2)
#   Number of Variables: 3
#   Variables:
#     - Name: a, Range: (-1.0, 1)
#     - Name: c, Range: (0.0, 1.0)
#     - Name: d, Range: (0.0, 1.0)
#
# Function 38:
#   Formula: e*x*log(1 + b/x)
#   Number of Variables: 2
#   Variables:
#     - Name: e, Range: (-1.0, 1)
#     - Name: b, Range: (0.0, 1.0)
#
# Function 39:
#   Formula: b*sqrt(1 - (x/c)**2)
#   Number of Variables: 2
#   Variables:
#     - Name: b, Range: (-1.0, 1)
#     - Name: c, Range: (0.1, 1.0)
#
# Function 40:
#   Formula: e*x**2/(1 + x**2)
#   Number of Variables: 1
#   Variables:
#     - Name: e, Range: (-1.0, 1)
#
# Function 41:
#   Formula: a*(x**2 - b**2)**(3/2)
#   Number of Variables: 2
#   Variables:
#     - Name: a, Range: (-1.0, 1)
#     - Name: b, Range: (0.0, 1.0)
#
# Function 42:
#   Formula: c*x*(1 - x/d)**2
#   Number of Variables: 2
#   Variables:
#     - Name: c, Range: (-1.0, 1)
#     - Name: d, Range: (0.1, 1.0)
#
# Function 43:
#   Formula: e*x/sqrt(1 + x**2)
#   Number of Variables: 1
#   Variables:
#     - Name: e, Range: (-1.0, 1)
#
# Function 44:
#   Formula: a*x**2/(1 + b*x**2)**2
#   Number of Variables: 2
#   Variables:
#     - Name: a, Range: (-1.0, 1)
#     - Name: b, Range: (0.0, 1.0)
#
# Function 45:
#   Formula: b*(1 - exp(-a*x))/x
#   Number of Variables: 2
#   Variables:
#     - Name: b, Range: (-1.0, 1)
#     - Name: a, Range: (0.0, 1.0)
#
# Function 46:
#   Formula: c*(1 - exp(-d*x**3))
#   Number of Variables: 2
#   Variables:
#     - Name: c, Range: (-1.0, 1)
#     - Name: d, Range: (0.0, 1.0)
#
# Function 47:
#   Formula: d*(x**2 - e**2)*log(x/e)
#   Number of Variables: 2
#   Variables:
#     - Name: d, Range: (-1.0, 1)
#     - Name: e, Range: (0.1, 1.0)
#
# Function 48:
#   Formula: c*x/(1 + d*x**4)**(1/4)
#   Number of Variables: 2
#   Variables:
#     - Name: c, Range: (-1.0, 1)
#     - Name: d, Range: (0.0, 1.0)
#
# Function 49:
#   Formula: e*(x**2 - a**2)/(x**4 + b**4)
#   Number of Variables: 3
#   Variables:
#     - Name: e, Range: (-1.0, 1)
#     - Name: a, Range: (0.0, 1.0)
#     - Name: b, Range: (0.1, 1.0)
#
# Function 50:
#   Formula: a*x**2/(1 + b*x**2 + c*x**4)
#   Number of Variables: 3
#   Variables:
#     - Name: a, Range: (-1.0, 1)
#     - Name: b, Range: (-1.0, 1.0)
#     - Name: c, Range: (0.0, 1.0)
#
# Function 51:
#   Formula: a*x**5 + b*x**3 + c*x
#   Number of Variables: 3
#   Variables:
#     - Name: a, Range: (-1.0, 1)
#     - Name: b, Range: (-1.0, 1.0)
#     - Name: c, Range: (-1.0, 1.0)
#
# Function 52:
#   Formula: (a*x + b)/(c*x + d)
#   Number of Variables: 4
#   Variables:
#     - Name: a, Range: (-1.0, 1)
#     - Name: b, Range: (-1.0, 1.0)
#     - Name: c, Range: (-1.0, 1.0)
#     - Name: d, Range: (-1.0, 1.0)
#
# Function 53:
#   Formula: a*x**(1/3) + b*x**(2/3)
#   Number of Variables: 2
#   Variables:
#     - Name: a, Range: (-1.0, 1)
#     - Name: b, Range: (-1.0, 1.0)
#
# Function 54:
#   Formula: a*log(x)**2 + b*log(x)
#   Number of Variables: 2
#   Variables:
#     - Name: a, Range: (-1.0, 1)
#     - Name: b, Range: (-1.0, 1.0)
#
# Function 55:
#   Formula: (a*x**2 + b)/(c*x**2 + d)
#   Number of Variables: 4
#   Variables:
#     - Name: a, Range: (-1.0, 1)
#     - Name: b, Range: (-1.0, 1.0)
#     - Name: c, Range: (-1.0, 1.0)
#     - Name: d, Range: (-1.0, 1.0)
#
# Function 56:
#   Formula: a(exp(b*x) - exp(-b*x))
#   Number of Variables: 2
#   Variables:
#     - Name: a, Range: (-1.0, 1)
#     - Name: b, Range: (0.0, 1.0)
#
# Function 57:
#   Formula: a*x**4/(1 + b*x**2)
#   Number of Variables: 2
#   Variables:
#     - Name: a, Range: (-1.0, 1)
#     - Name: b, Range: (0.0, 1.0)
#
# Function 58:
#   Formula: (a*x**3 + b*x)/(c*x**2 + d)
#   Number of Variables: 4
#   Variables:
#     - Name: a, Range: (-1.0, 1)
#     - Name: b, Range: (-1.0, 1.0)
#     - Name: c, Range: (-1.0, 1.0)
#     - Name: d, Range: (-1.0, 1.0)
#
# Function 59:
#   Formula: a*x**2*log(b*x)
#   Number of Variables: 2
#   Variables:
#     - Name: a, Range: (-1.0, 1)
#     - Name: b, Range: (0.1, 1.0)
#
# Function 60:
#   Formula: a*(x + b)**(1/c)
#   Number of Variables: 3
#   Variables:
#     - Name: a, Range: (-1.0, 1)
#     - Name: b, Range: (-1.0, 1.0)
#     - Name: c, Range: (0.1, 1.0)
#
# Function 61:
#   Formula: (a*x**2 + b*x)/(c*x + d)
#   Number of Variables: 4
#   Variables:
#     - Name: a, Range: (-1.0, 1)
#     - Name: b, Range: (-1.0, 1.0)
#     - Name: c, Range: (-1.0, 1.0)
#     - Name: d, Range: (-1.0, 1.0)
#
# Function 62:
#   Formula: a*x**3/(b + c*x**2)
#   Number of Variables: 3
#   Variables:
#     - Name: a, Range: (-1.0, 1)
#     - Name: b, Range: (0.1, 1.0)
#     - Name: c, Range: (0.0, 1.0)
#
# Function 63:
#   Formula: a*(1 - exp(-b*x**2))
#   Number of Variables: 2
#   Variables:
#     - Name: a, Range: (-1.0, 1)
#     - Name: b, Range: (0.0, 1.0)
#
# Function 64:
#   Formula: a*x**2/(b + c*x)**2
#   Number of Variables: 3
#   Variables:
#     - Name: a, Range: (-1.0, 1)
#     - Name: b, Range: (0.1, 1.0)
#     - Name: c, Range: (-1.0, 1.0)
#
# Function 65:
#   Formula: (a*x**2 + b)/(x**2 + c)
#   Number of Variables: 3
#   Variables:
#     - Name: a, Range: (-1.0, 1)
#     - Name: b, Range: (-1.0, 1.0)
#     - Name: c, Range: (0.1, 1.0)
#
# Function 66:
#   Formula: a*log(1 + b*x**2)
#   Number of Variables: 2
#   Variables:
#     - Name: a, Range: (-1.0, 1)
#     - Name: b, Range: (0.0, 1.0)
#
# Function 67:
#   Formula: a*x**3*exp(-b*x)
#   Number of Variables: 2
#   Variables:
#     - Name: a, Range: (-1.0, 1)
#     - Name: b, Range: (0.0, 1.0)
#
# Function 68:
#   Formula: (a*x + b)*c
#   Number of Variables: 3
#   Variables:
#     - Name: a, Range: (-1.0, 1)
#     - Name: b, Range: (-1.0, 1.0)
#     - Name: c, Range: (0.1, 1.0)
#
# Function 69:
#   Formula: a*(x**2 - b**2)**2
#   Number of Variables: 2
#   Variables:
#     - Name: a, Range: (-1.0, 1)
#     - Name: b, Range: (0.0, 1.0)
#
# Function 70:
#   Formula: a*x**4/(1 + b*x**4)
#   Number of Variables: 2
#   Variables:
#     - Name: a, Range: (-1.0, 1)
#     - Name: b, Range: (0.0, 1.0)
#
# Function 71:
#   Formula: m*x**2/2
#   Number of Variables: 1
#   Variables:
#     - Name: m, Range: (0.1, 1)
#
# Function 72:
#   Formula: a*log(x + sqrt(x**2 + b))
#   Number of Variables: 2
#   Variables:
#     - Name: a, Range: (-1.0, 1)
#     - Name: b, Range: (0.0, 1.0)
#
# Function 73:
#   Formula: a(exp(b*x) - 1)/(exp(b*x) + 1)
#   Number of Variables: 2
#   Variables:
#     - Name: a, Range: (-1.0, 1)
#     - Name: b, Range: (-1.0, 1.0)
#
# Function 74:
#   Formula: a*x**3/(1 + b*x + c*x**2)
#   Number of Variables: 3
#   Variables:
#     - Name: a, Range: (-1.0, 1)
#     - Name: b, Range: (-1.0, 1.0)
#     - Name: c, Range: (0.0, 1.0)
#
# Function 75:
#   Formula: (a*x**2 + b)/(c*x**2 + d*x + e)
#   Number of Variables: 5
#   Variables:
#     - Name: a, Range: (-1.0, 1)
#     - Name: b, Range: (-1.0, 1.0)
#     - Name: c, Range: (-1.0, 1.0)
#     - Name: d, Range: (-1.0, 1.0)
#     - Name: e, Range: (-1.0, 1.0)
#
# Function 76:
#   Formula: a(1 - (1 + b*x)*exp(-b*x))
#   Number of Variables: 2
#   Variables:
#     - Name: a, Range: (-1.0, 1)
#     - Name: b, Range: (0.0, 1.0)
#
# Function 77:
#   Formula: a*x**2*exp(-b*sqrt(x))
#   Number of Variables: 2
#   Variables:
#     - Name: a, Range: (-1.0, 1)
#     - Name: b, Range: (0.0, 1.0)
#
# Function 78:
#   Formula: (a*x**3 + b*x)/(c*x**2 + d*x + e)
#   Number of Variables: 5
#   Variables:
#     - Name: a, Range: (-1.0, 1)
#     - Name: b, Range: (-1.0, 1.0)
#     - Name: c, Range: (-1.0, 1.0)
#     - Name: d, Range: (-1.0, 1.0)
#     - Name: e, Range: (-1.0, 1.0)
#
# Function 79:
#   Formula: a*(x**4 - b*x**2)
#   Number of Variables: 2
#   Variables:
#     - Name: a, Range: (-1.0, 1)
#     - Name: b, Range: (0.0, 1.0)
#
# Function 80:
#   Formula: a*x**2/(b + c*x)**3
#   Number of Variables: 3
#   Variables:
#     - Name: a, Range: (-1.0, 1)
#     - Name: b, Range: (0.1, 1.0)
#     - Name: c, Range: (-1.0, 1.0)
#
# Function 81:
#   Formula: (a*x + b)/(c*sqrt(x) + d)
#   Number of Variables: 4
#   Variables:
#     - Name: a, Range: (-1.0, 1)
#     - Name: b, Range: (-1.0, 1.0)
#     - Name: c, Range: (-1.0, 1.0)
#     - Name: d, Range: (-1.0, 1.0)
#
# Function 82:
#   Formula: a*log(x)**3 + b*log(x)**2 + c*log(x)
#   Number of Variables: 3
#   Variables:
#     - Name: a, Range: (-1.0, 1)
#     - Name: b, Range: (-1.0, 1.0)
#     - Name: c, Range: (-1.0, 1.0)
#
# Function 83:
#   Formula: a*x**3/(1 + b*x**3)
#   Number of Variables: 2
#   Variables:
#     - Name: a, Range: (-1.0, 1)
#     - Name: b, Range: (0.0, 1.0)
#
# Function 84:
#   Formula: (a*x**2 + b*x)/(sqrt(c*x**2 + d))
#   Number of Variables: 4
#   Variables:
#     - Name: a, Range: (-1.0, 1)
#     - Name: b, Range: (-1.0, 1.0)
#     - Name: c, Range: (0.1, 1.0)
#     - Name: d, Range: (0.1, 1.0)
#
# Function 85:
#   Formula: a(1 - exp(-b*x**3))
#   Number of Variables: 2
#   Variables:
#     - Name: a, Range: (-1.0, 1)
#     - Name: b, Range: (0.0, 1.0)
#
# Function 86:
#   Formula: a*x**2*log(1 + b*x)
#   Number of Variables: 2
#   Variables:
#     - Name: a, Range: (-1.0, 1)
#     - Name: b, Range: (0.0, 1.0)
#
# Function 87:
#   Formula: (a*x**3 + b)/(c*x + d)
#   Number of Variables: 4
#   Variables:
#     - Name: a, Range: (-1.0, 1)
#     - Name: b, Range: (-1.0, 1.0)
#     - Name: c, Range: (-1.0, 1.0)
#     - Name: d, Range: (-1.0, 1.0)
#
# Function 88:
#   Formula: a*(x**3 - b*x)**2
#   Number of Variables: 2
#   Variables:
#     - Name: a, Range: (-1.0, 1)
#     - Name: b, Range: (0.0, 1.0)
#
# Function 89:
#   Formula: a*x**4/(1 + b*x + c*x**2)
#   Number of Variables: 3
#   Variables:
#     - Name: a, Range: (-1.0, 1)
#     - Name: b, Range: (-1.0, 1.0)
#     - Name: c, Range: (0.0, 1.0)
#
# Function 90:
#   Formula: (a*x**2 + b*x)/(c*x**3 + d*x + e)
#   Number of Variables: 5
#   Variables:
#     - Name: a, Range: (-1.0, 1)
#     - Name: b, Range: (-1.0, 1.0)
#     - Name: c, Range: (-1.0, 1.0)
#     - Name: d, Range: (-1.0, 1.0)
#     - Name: e, Range: (-1.0, 1.0)
#
# Function 91:
#   Formula: a*log(x + b)**2
#   Number of Variables: 2
#   Variables:
#     - Name: a, Range: (-1.0, 1)
#     - Name: b, Range: (0.1, 1.0)
#
# Function 92:
#   Formula: a(exp(b*x**2) - 1)/(exp(b*x**2) + 1)
#   Number of Variables: 2
#   Variables:
#     - Name: a, Range: (-1.0, 1)
#     - Name: b, Range: (-1.0, 1.0)
#
# Function 93:
#   Formula: a*x**5/(1 + b*x**2 + c*x**4)
#   Number of Variables: 3
#   Variables:
#     - Name: a, Range: (-1.0, 1)
#     - Name: b, Range: (0.0, 1.0)
#     - Name: c, Range: (0.0, 1.0)
#
# Function 94:
#   Formula: (a*x**3 + b*x**2)/(c*x + d)
#   Number of Variables: 4
#   Variables:
#     - Name: a, Range: (-1.0, 1)
#     - Name: b, Range: (-1.0, 1.0)
#     - Name: c, Range: (-1.0, 1.0)
#     - Name: d, Range: (-1.0, 1.0)
#
# Function 95:
#   Formula: a(1 - (1 + b*x + (b*x)**2/2)*exp(-b*x))
#   Number of Variables: 2
#   Variables:
#     - Name: a, Range: (-1.0, 1)
#     - Name: b, Range: (0.0, 1.0)
#
# Function 96:
#   Formula: a*x**3*exp(-b*x**2)
#   Number of Variables: 2
#   Variables:
#     - Name: a, Range: (-1.0, 1)
#     - Name: b, Range: (0.0, 1.0)
#
# Function 97:
#   Formula: (a*x**4 + b*x**2)/(c*x**2 + d*x + e)
#   Number of Variables: 5
#   Variables:
#     - Name: a, Range: (-1.0, 1)
#     - Name: b, Range: (-1.0, 1.0)
#     - Name: c, Range: (-1.0, 1.0)
#     - Name: d, Range: (-1.0, 1.0)
#     - Name: e, Range: (-1.0, 1.0)
#
# Function 98:
#   Formula: a*(x**5 - b*x**3)
#   Number of Variables: 2
#   Variables:
#     - Name: a, Range: (-1.0, 1)
#     - Name: b, Range: (0.0, 1.0)
#
# Function 99:
#   Formula: log(a*x + b)
#   Number of Variables: 2
#   Variables:
#     - Name: a, Range: (0.1, 1)
#     - Name: b, Range: (0.1, 1.0)
#
# Function 100:
#   Formula: a*log(b*x + sqrt((b*x)**2 + 1))
#   Number of Variables: 2
#   Variables:
#     - Name: a, Range: (-1.0, 1)
#     - Name: b, Range: (0.1, 1.0)

# %%
def generate_function(function, sample_size, x, max_vars, device):
    sympy_symbols = []
    param_tensors = []
    
    for var in function["variables"]:
        sym = sp.symbols(var["name"])
        sympy_symbols.append(sym)
        min_val, max_val = var["low"], var["high"]
        param = (max_val - min_val) * torch.rand(sample_size, 1, device=device) + min_val
        param_tensors.append(param)
    sympy_symbols.append(sp.symbols('x'))
    params = torch.cat(param_tensors, dim=1)
    padded_params = F.pad(params, pad=(0, max_vars - params.size(1)))
    padded_params = padded_params.expand(sample_size, max_vars)
    formula = sp.sympify(function["formula"])
    eval_func = sp.lambdify(sympy_symbols, formula, modules="numpy")
        
    results = []
    for xi in x:
        input_values = torch.cat([params, xi.expand(sample_size, 1)], dim=1)
        results.append(eval_func(*input_values.T))
    results = torch.stack(results, dim=1)
    
    return [results, formula, sympy_symbols, padded_params]

# %%
sample_size = 10000
sequence_length = 100
num_funcs = 10
max_vars = 5

x_values = torch.linspace(-1, 1, sequence_length).to(device)
hold = []
for f in range(num_funcs):
    try:
        results = generate_function(functions[f], sample_size, x_values, max_vars, device)
        results.append(f)
        funcs = torch.zeros(num_funcs)
        funcs[f] = 1
        results.append(funcs)
        hold.append(results)        
    except Exception as e:
        print(f"Error processing function {f}: {e}")

# %%
y_values = torch.stack([l[0] for l in hold])
formulas = [l[1] for l in hold]
symbols = [l[2] for l in hold]
param_values = [l[3] for l in hold]
num_params = torch.tensor([len(l[2])-1 for l in hold])
function_labels = [l[4] for l in hold]
target_funcs = [l[5] for l in hold]
target_funcs = torch.stack(target_funcs)
target_funcs = target_funcs.repeat_interleave(sample_size, dim=0)

# %%
full_params = torch.zeros(num_funcs, sample_size, num_funcs*max_vars)
for f in range(num_funcs):
    for i in range(sample_size):
        full_params[f, i, f*max_vars:f*max_vars+max_vars] = param_values[f][i]
param_values = torch.stack(param_values)
full_params = full_params.flatten(0, 1)

# %%
torch.save({
    'x_values': x_values,
    'y_values': y_values,
    'target_funcs': target_funcs
}, 'hold_data1.pth')

torch.save({
    'formulas': formulas,
    'symbols': symbols,
}, 'hold_data2.pth')

torch.save({
    'param_values': param_values,
    'full_params': full_params,
    'num_params': num_params
}, 'hold_data3.pth')

# %%
fig, axes = plt.subplots((num_funcs+1)//2, 2, figsize=(12, 4*(num_funcs+1)//2))
axes = axes.flatten()

for f in range(num_funcs):
    axes[f].plot(x_values.cpu().numpy(), y_values[f, 0].cpu().numpy())
